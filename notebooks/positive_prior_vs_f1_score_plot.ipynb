# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from nci_eval.plots import PositivePriorF1ScorePlot

# %%
PositivePriorF1ScorePlot().plot(tpr1=0.9, fpr1=0.01, tpr2=0.6, fpr2=0.001, positive_priors=np.logspace(-6, 0, num=100))
